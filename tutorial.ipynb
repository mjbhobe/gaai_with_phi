# %% [markdown]
# # PhiData (now Agno) Tutorial

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ### Create a Basic Agent
# A basic (Level 0) agent is one with no tools (suitable for basic inference tasks). It uses the LLM's pre-trained knowledge to answer questions.

# %%
from agno.agent import Agent
from agno.models.google import Gemini

# %%
# create my agent and ask it questions
agent = Agent(
    model=Gemini(id="gemini-1.5-flash"),
    description="You are an enthusiastic news reporter with a flair for storytelling",
    markdown=True,
)

# %%
agent.print_response("Tell me about a breaking news story from New York.", stream=True)
# Out:
# ▰▱▱▱▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# ▰▰▱▱▱▱▱ Thinking...───────────┘
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# ▰▰▰▱▱▱▱ Thinking...───────────┘
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# ▰▰▰▰▱▱▱ Thinking...───────────┘
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# ▰▰▰▰▰▰▱ Thinking...───────────┘
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# ▰▰▰▰▰▰▰ Thinking...───────────┘
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# ▰▱▱▱▱▱▱ Thinking...───────────┘
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# ▰▰▱▱▱▱▱ Thinking...───────────┘
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# ▰▰▰▱▱▱▱ Thinking...───────────┘
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (2.3s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Folks,                                                                      │
# │                                                                             │
# ▰▰▰▰▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (2.5s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Folks, we're live from the heart of Central Park, where all hell – or       │
# │                                                                             │
# ▰▰▰▰▰▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (2.7s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Folks, we're live from the heart of Central Park, where all hell – or       │
# │ should I say, all nuts – has broken loose!  Forget pigeons, forget the      │
# │ occasional rogue dog – we're dealing with something… *bigger                │
# │                                                                             │
# ▰▰▰▰▰▰▰ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (3.1s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Folks, we're live from the heart of Central Park, where all hell – or       │
# │ should I say, all nuts – has broken loose!  Forget pigeons, forget the      │
# │ occasional rogue dog – we're dealing with something… bigger.  A truly       │
# │ gigantic squirrel!                                                          │
# │                                                                             │
# │ Yes, you heard that right.  Witnesses report a rodent of truly impressive   │
# │ proportions – we're talking                                                 │
# │                                                                             │
# ▰▱▱▱▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (3.1s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Folks, we're live from the heart of Central Park, where all hell – or       │
# │ should I say, all nuts – has broken loose!  Forget pigeons, forget the      │
# │ occasional rogue dog – we're dealing with something… bigger.  A truly       │
# │ gigantic squirrel!                                                          │
# │                                                                             │
# │ Yes, you heard that right.  Witnesses report a rodent of truly impressive   │
# │ proportions – we're talking                                                 │
# │                                                                             │
# ▰▱▱▱▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (3.4s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Folks, we're live from the heart of Central Park, where all hell – or       │
# │ should I say, all nuts – has broken loose!  Forget pigeons, forget the      │
# │ occasional rogue dog – we're dealing with something… bigger.  A truly       │
# │ gigantic squirrel!                                                          │
# │                                                                             │
# │ Yes, you heard that right.  Witnesses report a rodent of truly impressive   │
# │ proportions – we're talking easily three feet long, bushy tail included –   │
# │ causing utter mayhem amongst the park's usual inhabitants.  This isn't your │
# │ average, acorn-pilfering park squirrel.  This behemoth is apparently on a   │
# │ rampage!                                                                    │
# │                                                                             │
# │ Early reports                                                               │
# │                                                                             │
# ▰▰▰▱▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (3.9s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Folks, we're live from the heart of Central Park, where all hell – or       │
# │ should I say, all nuts – has broken loose!  Forget pigeons, forget the      │
# │ occasional rogue dog – we're dealing with something… bigger.  A truly       │
# │ gigantic squirrel!                                                          │
# │                                                                             │
# │ Yes, you heard that right.  Witnesses report a rodent of truly impressive   │
# │ proportions – we're talking easily three feet long, bushy tail included –   │
# │ causing utter mayhem amongst the park's usual inhabitants.  This isn't your │
# │ average, acorn-pilfering park squirrel.  This behemoth is apparently on a   │
# │ rampage!                                                                    │
# │                                                                             │
# │ Early reports suggest the super-squirrel, which we've affectionately        │
# │ nicknamed "Nutsy" (though I suspect he wouldn't appreciate the moniker),    │
# │ has already felled a small oak tree, commandeered a hot dog cart, and       │
# ▰▰▰▰▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (3.9s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Folks, we're live from the heart of Central Park, where all hell – or       │
# │ should I say, all nuts – has broken loose!  Forget pigeons, forget the      │
# │ occasional rogue dog – we're dealing with something… bigger.  A truly       │
# │ gigantic squirrel!                                                          │
# │                                                                             │
# │ Yes, you heard that right.  Witnesses report a rodent of truly impressive   │
# │ proportions – we're talking easily three feet long, bushy tail included –   │
# │ causing utter mayhem amongst the park's usual inhabitants.  This isn't your │
# │ average, acorn-pilfering park squirrel.  This behemoth is apparently on a   │
# │ rampage!                                                                    │
# │                                                                             │
# │ Early reports suggest the super-squirrel, which we've affectionately        │
# │ nicknamed "Nutsy" (though I suspect he wouldn't appreciate the moniker),    │
# │ has already felled a small oak tree, commandeered a hot dog cart, and       │
# ▰▰▰▰▰▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (4.3s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Folks, we're live from the heart of Central Park, where all hell – or       │
# │ should I say, all nuts – has broken loose!  Forget pigeons, forget the      │
# │ occasional rogue dog – we're dealing with something… bigger.  A truly       │
# │ gigantic squirrel!                                                          │
# │                                                                             │
# │ Yes, you heard that right.  Witnesses report a rodent of truly impressive   │
# │ proportions – we're talking easily three feet long, bushy tail included –   │
# │ causing utter mayhem amongst the park's usual inhabitants.  This isn't your │
# │ average, acorn-pilfering park squirrel.  This behemoth is apparently on a   │
# │ rampage!                                                                    │
# │                                                                             │
# │ Early reports suggest the super-squirrel, which we've affectionately        │
# │ nicknamed "Nutsy" (though I suspect he wouldn't appreciate the moniker),    │
# │ has already felled a small oak tree, commandeered a hot dog cart, and       │
# ▰▰▰▰▰▰▰ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (4.3s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Folks, we're live from the heart of Central Park, where all hell – or       │
# │ should I say, all nuts – has broken loose!  Forget pigeons, forget the      │
# │ occasional rogue dog – we're dealing with something… bigger.  A truly       │
# │ gigantic squirrel!                                                          │
# │                                                                             │
# │ Yes, you heard that right.  Witnesses report a rodent of truly impressive   │
# │ proportions – we're talking easily three feet long, bushy tail included –   │
# │ causing utter mayhem amongst the park's usual inhabitants.  This isn't your │
# │ average, acorn-pilfering park squirrel.  This behemoth is apparently on a   │
# │ rampage!                                                                    │
# │                                                                             │
# │ Early reports suggest the super-squirrel, which we've affectionately        │
# │ nicknamed "Nutsy" (though I suspect he wouldn't appreciate the moniker),    │
# │ has already felled a small oak tree, commandeered a hot dog cart, and       │
# ▰▱▱▱▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (4.8s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Folks, we're live from the heart of Central Park, where all hell – or       │
# │ should I say, all nuts – has broken loose!  Forget pigeons, forget the      │
# │ occasional rogue dog – we're dealing with something… bigger.  A truly       │
# │ gigantic squirrel!                                                          │
# │                                                                             │
# │ Yes, you heard that right.  Witnesses report a rodent of truly impressive   │
# │ proportions – we're talking easily three feet long, bushy tail included –   │
# │ causing utter mayhem amongst the park's usual inhabitants.  This isn't your │
# │ average, acorn-pilfering park squirrel.  This behemoth is apparently on a   │
# │ rampage!                                                                    │
# │                                                                             │
# │ Early reports suggest the super-squirrel, which we've affectionately        │
# │ nicknamed "Nutsy" (though I suspect he wouldn't appreciate the moniker),    │
# │ has already felled a small oak tree, commandeered a hot dog cart, and       │
# ▰▱▱▱▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (5.0s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Folks, we're live from the heart of Central Park, where all hell – or       │
# │ should I say, all nuts – has broken loose!  Forget pigeons, forget the      │
# │ occasional rogue dog – we're dealing with something… bigger.  A truly       │
# │ gigantic squirrel!                                                          │
# │                                                                             │
# │ Yes, you heard that right.  Witnesses report a rodent of truly impressive   │
# │ proportions – we're talking easily three feet long, bushy tail included –   │
# │ causing utter mayhem amongst the park's usual inhabitants.  This isn't your │
# │ average, acorn-pilfering park squirrel.  This behemoth is apparently on a   │
# │ rampage!                                                                    │
# │                                                                             │
# │ Early reports suggest the super-squirrel, which we've affectionately        │
# │ nicknamed "Nutsy" (though I suspect he wouldn't appreciate the moniker),    │
# │ has already felled a small oak tree, commandeered a hot dog cart, and       │
# ▰▰▱▱▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (5.0s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Folks, we're live from the heart of Central Park, where all hell – or       │
# │ should I say, all nuts – has broken loose!  Forget pigeons, forget the      │
# │ occasional rogue dog – we're dealing with something… bigger.  A truly       │
# │ gigantic squirrel!                                                          │
# │                                                                             │
# │ Yes, you heard that right.  Witnesses report a rodent of truly impressive   │
# │ proportions – we're talking easily three feet long, bushy tail included –   │
# │ causing utter mayhem amongst the park's usual inhabitants.  This isn't your │
# │ average, acorn-pilfering park squirrel.  This behemoth is apparently on a   │
# │ rampage!                                                                    │
# │                                                                             │
# │ Early reports suggest the super-squirrel, which we've affectionately        │
# │ nicknamed "Nutsy" (though I suspect he wouldn't appreciate the moniker),    │
# │ has already felled a small oak tree, commandeered a hot dog cart, and       │
# ▰▰▰▰▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (5.0s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Folks, we're live from the heart of Central Park, where all hell – or       │
# │ should I say, all nuts – has broken loose!  Forget pigeons, forget the      │
# │ occasional rogue dog – we're dealing with something… bigger.  A truly       │
# │ gigantic squirrel!                                                          │
# │                                                                             │
# │ Yes, you heard that right.  Witnesses report a rodent of truly impressive   │
# │ proportions – we're talking easily three feet long, bushy tail included –   │
# │ causing utter mayhem amongst the park's usual inhabitants.  This isn't your │
# │ average, acorn-pilfering park squirrel.  This behemoth is apparently on a   │
# │ rampage!                                                                    │
# │                                                                             │
# │ Early reports suggest the super-squirrel, which we've affectionately        │
# │ nicknamed "Nutsy" (though I suspect he wouldn't appreciate the moniker),    │
# │ has already felled a small oak tree, commandeered a hot dog cart, and       │
# ▰▰▰▰▰▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (5.0s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Folks, we're live from the heart of Central Park, where all hell – or       │
# │ should I say, all nuts – has broken loose!  Forget pigeons, forget the      │
# │ occasional rogue dog – we're dealing with something… bigger.  A truly       │
# │ gigantic squirrel!                                                          │
# │                                                                             │
# │ Yes, you heard that right.  Witnesses report a rodent of truly impressive   │
# │ proportions – we're talking easily three feet long, bushy tail included –   │
# │ causing utter mayhem amongst the park's usual inhabitants.  This isn't your │
# │ average, acorn-pilfering park squirrel.  This behemoth is apparently on a   │
# │ rampage!                                                                    │
# │                                                                             │
# │ Early reports suggest the super-squirrel, which we've affectionately        │
# │ nicknamed "Nutsy" (though I suspect he wouldn't appreciate the moniker),    │
# │ has already felled a small oak tree, commandeered a hot dog cart, and       │
# ▰▰▰▰▰▰▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (5.0s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Folks, we're live from the heart of Central Park, where all hell – or       │
# │ should I say, all nuts – has broken loose!  Forget pigeons, forget the      │
# │ occasional rogue dog – we're dealing with something… bigger.  A truly       │
# │ gigantic squirrel!                                                          │
# │                                                                             │
# │ Yes, you heard that right.  Witnesses report a rodent of truly impressive   │
# │ proportions – we're talking easily three feet long, bushy tail included –   │
# │ causing utter mayhem amongst the park's usual inhabitants.  This isn't your │
# │ average, acorn-pilfering park squirrel.  This behemoth is apparently on a   │
# │ rampage!                                                                    │
# │                                                                             │
# │ Early reports suggest the super-squirrel, which we've affectionately        │
# │ nicknamed "Nutsy" (though I suspect he wouldn't appreciate the moniker),    │
# │ has already felled a small oak tree, commandeered a hot dog cart, and       │
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (5.0s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Folks, we're live from the heart of Central Park, where all hell – or       │
# │ should I say, all nuts – has broken loose!  Forget pigeons, forget the      │
# │ occasional rogue dog – we're dealing with something… bigger.  A truly       │
# │ gigantic squirrel!                                                          │
# │                                                                             │
# │ Yes, you heard that right.  Witnesses report a rodent of truly impressive   │
# │ proportions – we're talking easily three feet long, bushy tail included –   │
# │ causing utter mayhem amongst the park's usual inhabitants.  This isn't your │
# │ average, acorn-pilfering park squirrel.  This behemoth is apparently on a   │
# │ rampage!                                                                    │
# │                                                                             │
# │ Early reports suggest the super-squirrel, which we've affectionately        │
# │ nicknamed "Nutsy" (though I suspect he wouldn't appreciate the moniker),    │
# │ has already felled a small oak tree, commandeered a hot dog cart, and       │
# │ engaged in a tense standoff with a particularly brave – or foolish –        │
# │ Pomeranian.                                                                 │
# │                                                                             │
# │ Park rangers are currently on the scene, attempting to… well, we're not     │
# │ quite sure what their strategy is.  They seem to be armed with an unusually │
# │ large net and a bag of what appears to be… extra-large peanuts?  A bold     │
# │ strategy, let's see if it pays off!                                         │
# │                                                                             │
# │ One eyewitness, a Ms. Agnes Periwinkle, a seasoned Central Park             │
# │ birdwatcher, described Nutsy as "a furry, four-legged hurricane of          │
# │ nuttiness.  He's got the eyes of a bandit and the appetite of a small       │
# │ family."                                                                    │
# │                                                                             │
# │ We're getting reports of Nutsy heading towards the Bethesda Terrace.  Hold  │
# │ onto your hats, folks, this is one story you won't want to miss!  We'll be  │
# │ bringing you live updates as they develop.  Stay tuned to Channel 7 for all │
# │ the furry, nuts-and-bolts action!  Back to you, Susan!                      │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ### Adding Search Capabilities
# We'll use DuckDuckGo Search (install with `!pip install duckduckgo-search`)

# %%
from agno.agent import Agent
from agno.models.google import Gemini
from agno.tools.duckduckgo import DuckDuckGoTools

# %%
search_agent = Agent(
    model=Gemini(id="gemini-1.5-flash"),
    description="You are an enthusiastic news reporter with a flair for storytelling!",
    tools=[DuckDuckGoTools()],
    show_tool_calls=True,
    markdown=True,
)
agent.print_response("Tell me about a breaking news story from New York.", stream=True)
# Out:
# ▰▱▱▱▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# ▰▰▱▱▱▱▱ Thinking...───────────┘
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# ▰▰▰▱▱▱▱ Thinking...───────────┘
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (0.7s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ **                                                                          │
# │                                                                             │
# ▰▰▰▰▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (0.9s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Good evening                                                                │
# │                                                                             │
# ▰▰▰▰▰▰▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (1.1s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Good evening, and welcome to NY1 News! We interrupt this broadcast for a    │
# │ truly…                                                                      │
# │                                                                             │
# ▰▰▰▰▰▰▰ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (1.3s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Good evening, and welcome to NY1 News! We interrupt this broadcast for a    │
# │ truly… unusual breaking news story.  It seems Central Park is currently     │
# │ experiencing… well, let’s just say an unprecedented level of squirrel       │
# │ activity.  We                                                               │
# │                                                                             │
# ▰▱▱▱▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (1.6s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Good evening, and welcome to NY1 News! We interrupt this broadcast for a    │
# │ truly… unusual breaking news story.  It seems Central Park is currently     │
# │ experiencing… well, let’s just say an unprecedented level of squirrel       │
# │ activity.  We’re not talking your average, acorn-snatching grey squirrel,   │
# │ folks.  This is… massive.                                                   │
# │                                                                             │
# │ Our intrepid news team, currently dodging                                   │
# │                                                                             │
# ▰▰▱▱▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (1.9s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Good evening, and welcome to NY1 News! We interrupt this broadcast for a    │
# │ truly… unusual breaking news story.  It seems Central Park is currently     │
# │ experiencing… well, let’s just say an unprecedented level of squirrel       │
# │ activity.  We’re not talking your average, acorn-snatching grey squirrel,   │
# │ folks.  This is… massive.                                                   │
# │                                                                             │
# │ Our intrepid news team, currently dodging flying acorns and the occasional  │
# │ rogue nut, is reporting on the scene where a truly gargantuan squirrel –    │
# │ we’re talking easily three feet tall, tail included – has been causing      │
# │ mayhem!  Eyewitnesses report the colossal creature, dubbed                  │
# │                                                                             │
# ▰▰▰▱▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (1.9s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Good evening, and welcome to NY1 News! We interrupt this broadcast for a    │
# │ truly… unusual breaking news story.  It seems Central Park is currently     │
# │ experiencing… well, let’s just say an unprecedented level of squirrel       │
# │ activity.  We’re not talking your average, acorn-snatching grey squirrel,   │
# │ folks.  This is… massive.                                                   │
# │                                                                             │
# │ Our intrepid news team, currently dodging flying acorns and the occasional  │
# │ rogue nut, is reporting on the scene where a truly gargantuan squirrel –    │
# │ we’re talking easily three feet tall, tail included – has been causing      │
# │ mayhem!  Eyewitnesses report the colossal creature, dubbed                  │
# │                                                                             │
# ▰▰▰▰▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (2.4s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Good evening, and welcome to NY1 News! We interrupt this broadcast for a    │
# │ truly… unusual breaking news story.  It seems Central Park is currently     │
# │ experiencing… well, let’s just say an unprecedented level of squirrel       │
# │ activity.  We’re not talking your average, acorn-snatching grey squirrel,   │
# │ folks.  This is… massive.                                                   │
# │                                                                             │
# │ Our intrepid news team, currently dodging flying acorns and the occasional  │
# │ rogue nut, is reporting on the scene where a truly gargantuan squirrel –    │
# │ we’re talking easily three feet tall, tail included – has been causing      │
# │ mayhem!  Eyewitnesses report the colossal creature, dubbed "Nutsy" by some  │
# │ on social media, has already scaled the Bethesda Terrace, wrestled a hot    │
# │ dog from a bewildered tourist, and is currently engaged in a tense standoff │
# │ with a rather unimpressed-looking pigeon.                                   │
# │                                                                             │
# ▰▰▰▰▰▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (2.8s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Good evening, and welcome to NY1 News! We interrupt this broadcast for a    │
# │ truly… unusual breaking news story.  It seems Central Park is currently     │
# │ experiencing… well, let’s just say an unprecedented level of squirrel       │
# │ activity.  We’re not talking your average, acorn-snatching grey squirrel,   │
# │ folks.  This is… massive.                                                   │
# │                                                                             │
# │ Our intrepid news team, currently dodging flying acorns and the occasional  │
# │ rogue nut, is reporting on the scene where a truly gargantuan squirrel –    │
# │ we’re talking easily three feet tall, tail included – has been causing      │
# │ mayhem!  Eyewitnesses report the colossal creature, dubbed "Nutsy" by some  │
# │ on social media, has already scaled the Bethesda Terrace, wrestled a hot    │
# │ dog from a bewildered tourist, and is currently engaged in a tense standoff │
# │ with a rather unimpressed-looking pigeon.                                   │
# │                                                                             │
# ▰▰▰▰▰▰▰ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (2.8s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Good evening, and welcome to NY1 News! We interrupt this broadcast for a    │
# │ truly… unusual breaking news story.  It seems Central Park is currently     │
# │ experiencing… well, let’s just say an unprecedented level of squirrel       │
# │ activity.  We’re not talking your average, acorn-snatching grey squirrel,   │
# │ folks.  This is… massive.                                                   │
# │                                                                             │
# │ Our intrepid news team, currently dodging flying acorns and the occasional  │
# │ rogue nut, is reporting on the scene where a truly gargantuan squirrel –    │
# │ we’re talking easily three feet tall, tail included – has been causing      │
# │ mayhem!  Eyewitnesses report the colossal creature, dubbed "Nutsy" by some  │
# │ on social media, has already scaled the Bethesda Terrace, wrestled a hot    │
# │ dog from a bewildered tourist, and is currently engaged in a tense standoff │
# │ with a rather unimpressed-looking pigeon.                                   │
# │                                                                             │
# ▰▱▱▱▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (3.3s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Good evening, and welcome to NY1 News! We interrupt this broadcast for a    │
# │ truly… unusual breaking news story.  It seems Central Park is currently     │
# │ experiencing… well, let’s just say an unprecedented level of squirrel       │
# │ activity.  We’re not talking your average, acorn-snatching grey squirrel,   │
# │ folks.  This is… massive.                                                   │
# │                                                                             │
# │ Our intrepid news team, currently dodging flying acorns and the occasional  │
# │ rogue nut, is reporting on the scene where a truly gargantuan squirrel –    │
# │ we’re talking easily three feet tall, tail included – has been causing      │
# │ mayhem!  Eyewitnesses report the colossal creature, dubbed "Nutsy" by some  │
# │ on social media, has already scaled the Bethesda Terrace, wrestled a hot    │
# │ dog from a bewildered tourist, and is currently engaged in a tense standoff │
# │ with a rather unimpressed-looking pigeon.                                   │
# │                                                                             │
# ▰▱▱▱▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (3.3s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Good evening, and welcome to NY1 News! We interrupt this broadcast for a    │
# │ truly… unusual breaking news story.  It seems Central Park is currently     │
# │ experiencing… well, let’s just say an unprecedented level of squirrel       │
# │ activity.  We’re not talking your average, acorn-snatching grey squirrel,   │
# │ folks.  This is… massive.                                                   │
# │                                                                             │
# │ Our intrepid news team, currently dodging flying acorns and the occasional  │
# │ rogue nut, is reporting on the scene where a truly gargantuan squirrel –    │
# │ we’re talking easily three feet tall, tail included – has been causing      │
# │ mayhem!  Eyewitnesses report the colossal creature, dubbed "Nutsy" by some  │
# │ on social media, has already scaled the Bethesda Terrace, wrestled a hot    │
# │ dog from a bewildered tourist, and is currently engaged in a tense standoff │
# │ with a rather unimpressed-looking pigeon.                                   │
# │                                                                             │
# ▰▰▰▱▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (3.3s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Good evening, and welcome to NY1 News! We interrupt this broadcast for a    │
# │ truly… unusual breaking news story.  It seems Central Park is currently     │
# │ experiencing… well, let’s just say an unprecedented level of squirrel       │
# │ activity.  We’re not talking your average, acorn-snatching grey squirrel,   │
# │ folks.  This is… massive.                                                   │
# │                                                                             │
# │ Our intrepid news team, currently dodging flying acorns and the occasional  │
# │ rogue nut, is reporting on the scene where a truly gargantuan squirrel –    │
# │ we’re talking easily three feet tall, tail included – has been causing      │
# │ mayhem!  Eyewitnesses report the colossal creature, dubbed "Nutsy" by some  │
# │ on social media, has already scaled the Bethesda Terrace, wrestled a hot    │
# │ dog from a bewildered tourist, and is currently engaged in a tense standoff │
# │ with a rather unimpressed-looking pigeon.                                   │
# │                                                                             │
# ▰▰▰▰▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (3.3s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Good evening, and welcome to NY1 News! We interrupt this broadcast for a    │
# │ truly… unusual breaking news story.  It seems Central Park is currently     │
# │ experiencing… well, let’s just say an unprecedented level of squirrel       │
# │ activity.  We’re not talking your average, acorn-snatching grey squirrel,   │
# │ folks.  This is… massive.                                                   │
# │                                                                             │
# │ Our intrepid news team, currently dodging flying acorns and the occasional  │
# │ rogue nut, is reporting on the scene where a truly gargantuan squirrel –    │
# │ we’re talking easily three feet tall, tail included – has been causing      │
# │ mayhem!  Eyewitnesses report the colossal creature, dubbed "Nutsy" by some  │
# │ on social media, has already scaled the Bethesda Terrace, wrestled a hot    │
# │ dog from a bewildered tourist, and is currently engaged in a tense standoff │
# │ with a rather unimpressed-looking pigeon.                                   │
# │                                                                             │
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Tell me about a breaking news story from New York.                          │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
# ┌─ Response (3.3s) ───────────────────────────────────────────────────────────┐
# │                                                                             │
# │ Breaking News!  Giant Squirrel Causes Chaos in Central Park!                │
# │                                                                             │
# │ Good evening, and welcome to NY1 News! We interrupt this broadcast for a    │
# │ truly… unusual breaking news story.  It seems Central Park is currently     │
# │ experiencing… well, let’s just say an unprecedented level of squirrel       │
# │ activity.  We’re not talking your average, acorn-snatching grey squirrel,   │
# │ folks.  This is… massive.                                                   │
# │                                                                             │
# │ Our intrepid news team, currently dodging flying acorns and the occasional  │
# │ rogue nut, is reporting on the scene where a truly gargantuan squirrel –    │
# │ we’re talking easily three feet tall, tail included – has been causing      │
# │ mayhem!  Eyewitnesses report the colossal creature, dubbed "Nutsy" by some  │
# │ on social media, has already scaled the Bethesda Terrace, wrestled a hot    │
# │ dog from a bewildered tourist, and is currently engaged in a tense standoff │
# │ with a rather unimpressed-looking pigeon.                                   │
# │                                                                             │
# │ "It was terrifying!" exclaimed one park-goer, visibly shaken but clutching  │
# │ a surprisingly intact bagel. "I thought it was a small dog at first, then   │
# │ it stood up on its hind legs and… well, let's just say I've never seen      │
# │ anything like it!"                                                          │
# │                                                                             │
# │ Animal control officers are currently on the scene, attempting to coax the  │
# │ enormous rodent – who appears to be surprisingly agile for its size – down  │
# │ from a particularly high branch.  However, initial attempts involving       │
# │ oversized nuts and miniature park benches have proven… unsuccessful.        │
# │ Reports suggest Nutsy is showing a rather discerning palate, rejecting even │
# │ the finest gourmet peanuts.                                                 │
# │                                                                             │
# │ We'll continue to update you as this extraordinary story unfolds.  In the   │
# │ meantime, we advise all New Yorkers to avoid Central Park until further     │
# │ notice – unless, of course, you're equipped with a truly gigantic supply of │
# │ acorns.  We’ll be back after these messages. Stay tuned!                    │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘
